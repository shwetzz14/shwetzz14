# %%
import shutil
# Corn
source_dir = "/kaggle/input/plantvillage-dataset/color/Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot"
destination_dir = "/kaggle/working/Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot"
shutil.copytree(source_dir, destination_dir)

source_dir = "/kaggle/input/plantvillage-dataset/color/Corn_(maize)___Common_rust_"
destination_dir = "/kaggle/working/Corn_(maize)___Common_rust_"
shutil.copytree(source_dir, destination_dir)

source_dir = "/kaggle/input/plantvillage-dataset/color/Corn_(maize)___Northern_Leaf_Blight"
destination_dir = "/kaggle/working/Corn_(maize)___Northern_Leaf_Blight"
shutil.copytree(source_dir, destination_dir)

source_dir = "/kaggle/input/plantvillage-dataset/color/Corn_(maize)___healthy"
destination_dir = "/kaggle/working/Corn_(maize)___healthy"
shutil.copytree(source_dir, destination_dir)

# Tomato
source_dir = "/kaggle/input/plantvillage-dataset/color/Tomato___Bacterial_spot"
destination_dir = "/kaggle/working/Tomato___Bacterial_spot"
shutil.copytree(source_dir, destination_dir)

source_dir = "/kaggle/input/plantvillage-dataset/color/Tomato___Early_blight"
destination_dir = "/kaggle/working/Tomato___Early_blight"
shutil.copytree(source_dir, destination_dir)

source_dir = "/kaggle/input/plantvillage-dataset/color/Tomato___Late_blight"
destination_dir = "/kaggle/working/Tomato___Late_blight"
shutil.copytree(source_dir, destination_dir)

source_dir = "/kaggle/input/plantvillage-dataset/color/Tomato___Leaf_Mold"
destination_dir = "/kaggle/working/Tomato___Leaf_Mold"
shutil.copytree(source_dir, destination_dir)


# Tomato
source_dir = "/kaggle/input/plantvillage-dataset/color/Tomato___Septoria_leaf_spot"
destination_dir = "/kaggle/working/Tomato___Septoria_leaf_spot"
shutil.copytree(source_dir, destination_dir)

source_dir = "/kaggle/input/plantvillage-dataset/color/Tomato___Spider_mites Two-spotted_spider_mite"
destination_dir = "/kaggle/working/Tomato___Spider_mites Two-spotted_spider_mite"
shutil.copytree(source_dir, destination_dir)

source_dir = "/kaggle/input/plantvillage-dataset/color/Tomato___Target_Spot"
destination_dir = "/kaggle/working/Tomato___Target_Spot"
shutil.copytree(source_dir, destination_dir)

source_dir = "/kaggle/input/plantvillage-dataset/color/Tomato___Tomato_Yellow_Leaf_Curl_Virus"
destination_dir = "/kaggle/working/Tomato___Tomato_Yellow_Leaf_Curl_Virus"
shutil.copytree(source_dir, destination_dir)

source_dir = "/kaggle/input/plantvillage-dataset/color/Tomato___Tomato_mosaic_virus"
destination_dir = "/kaggle/working/Tomato___Tomato_mosaic_virus" 
shutil.copytree(source_dir, destination_dir)

source_dir = "/kaggle/input/plantvillage-dataset/color/Tomato___healthy"
destination_dir = "/kaggle/working/Tomato___healthy"
shutil.copytree(source_dir, destination_dir)

# Apple
source_dir = "/kaggle/input/plantvillage-dataset/color/Apple___Apple_scab"
destination_dir = "/kaggle/working/Apple___Apple_scab"
shutil.copytree(source_dir, destination_dir)

source_dir = "/kaggle/input/plantvillage-dataset/color/Apple___Black_rot"
destination_dir = "/kaggle/working/Apple___Black_rot"
shutil.copytree(source_dir, destination_dir)

source_dir = "/kaggle/input/plantvillage-dataset/color/Apple___Cedar_apple_rust"
destination_dir = "/kaggle/working/Apple___Cedar_apple_rust"
shutil.copytree(source_dir, destination_dir)

source_dir = "/kaggle/input/plantvillage-dataset/color/Apple___healthy"
destination_dir = "/kaggle/working/Apple___healthy"
shutil.copytree(source_dir, destination_dir)


# Potato
source_dir = "/kaggle/input/plantvillage-dataset/color/Potato___Early_blight"
destination_dir = "/kaggle/working/Potato___Early_blight"
shutil.copytree(source_dir, destination_dir)

source_dir = "/kaggle/input/plantvillage-dataset/color/Potato___Late_blight"
destination_dir = "/kaggle/working/Potato___Late_blight"
shutil.copytree(source_dir, destination_dir)

source_dir = "/kaggle/input/plantvillage-dataset/color/Potato___healthy"
destination_dir = "/kaggle/working/Potato___healthy"
shutil.copytree(source_dir, destination_dir)
# Out:
# '/kaggle/working/Potato___healthy'

# %%
import numpy as np 
import pandas as pd 
import os

# %%
path = '/kaggle/working/'

# %%
filenames = os.listdir(path)
len(filenames)
# Out:
# 22

# %%
filenames[:]
# Out:
# ['Corn_(maize)___Common_rust_',
#  'Tomato___Early_blight',
#  '.virtual_documents',
#  'Potato___Early_blight',
#  'Apple___healthy',
#  'Potato___healthy',
#  'Tomato___Leaf_Mold',
#  'Tomato___healthy',
#  'Apple___Apple_scab',
#  'Tomato___Bacterial_spot',
#  'Corn_(maize)___Northern_Leaf_Blight',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Tomato___Tomato_mosaic_virus',
#  'Potato___Late_blight',
#  'Apple___Cedar_apple_rust',
#  'Tomato___Late_blight',
#  'Apple___Black_rot',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
#  'Tomato___Septoria_leaf_spot',
#  'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot',
#  'Tomato___Target_Spot',
#  'Corn_(maize)___healthy']

# %%
import cv2
image = cv2.imread("/kaggle/input/plantvillage-dataset/color/Corn_(maize)___Common_rust_/RS_Rust 1563.JPG")

# %%
import matplotlib.pyplot as plt
print(image.shape)
plt.imshow(image)
plt.title('Corn Common Rust', size=18)
plt.axis('off') 
plt.show()
# Out:
# (256, 256, 3)

# %%
image = cv2.imread("../input/plantvillage-dataset/color/Peach___Bacterial_spot/00e6ad4a-5a62-48d7-ac68-9c0b8ec87f5f___Rut._Bact.S 1472.JPG")
plt.imshow(image)
plt.title('Peach Bacterial spot', size=18)
plt.axis('off')
plt.show()

# %%
classes = [d for d in os.listdir(path) if os.path.isdir(os.path.join(path, d))]

print("Dataset Classes:")
for cls in classes:
    print(cls)
# Out:
# Dataset Classes:
# Corn_(maize)___Common_rust_
# Tomato___Early_blight
# .virtual_documents
# Potato___Early_blight
# Apple___healthy
# Potato___healthy
# Tomato___Leaf_Mold
# Tomato___healthy
# Apple___Apple_scab
# Tomato___Bacterial_spot
# Corn_(maize)___Northern_Leaf_Blight
# Tomato___Spider_mites Two-spotted_spider_mite
# Tomato___Tomato_mosaic_virus
# Potato___Late_blight
# Apple___Cedar_apple_rust
# Tomato___Late_blight
# Apple___Black_rot
# Tomato___Tomato_Yellow_Leaf_Curl_Virus
# Tomato___Septoria_leaf_spot
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
# Tomato___Target_Spot
# Corn_(maize)___healthy

# %%
def create_dataframe(data_path):
    filepaths = []
    labels = []

    for fold in os.listdir(path):
        f_path = os.path.join(data_path, fold)
        if os.path.isdir(f_path):
            imgs = os.listdir(f_path)
            for img in imgs:
                img_path = os.path.join(f_path, img)
                filepaths.append(img_path)
                labels.append(fold)

    fseries = pd.Series(filepaths, name='Filepaths')
    lseries = pd.Series(labels, name='Labels')
    return pd.concat([fseries, lseries], axis=1)

# Create DataFrame for the dataset
df = create_dataframe(path)

# %%
df
# Out:
#                                                Filepaths  \
# 0      /kaggle/working/Corn_(maize)___Common_rust_/RS...
# 1      /kaggle/working/Corn_(maize)___Common_rust_/RS...
# 2      /kaggle/working/Corn_(maize)___Common_rust_/RS...
# 3      /kaggle/working/Corn_(maize)___Common_rust_/RS...
# 4      /kaggle/working/Corn_(maize)___Common_rust_/RS...
# ...                                                  ...
# 27330  /kaggle/working/Corn_(maize)___healthy/cf13f3b...
# 27331  /kaggle/working/Corn_(maize)___healthy/1c94fdf...
# 27332  /kaggle/working/Corn_(maize)___healthy/38618a5...
# 27333  /kaggle/working/Corn_(maize)___healthy/44f2a3c...
# 27334  /kaggle/working/Corn_(maize)___healthy/60d4196...
#
#                             Labels
# 0      Corn_(maize)___Common_rust_
# 1      Corn_(maize)___Common_rust_
# 2      Corn_(maize)___Common_rust_
# 3      Corn_(maize)___Common_rust_
# 4      Corn_(maize)___Common_rust_
# ...                            ...
# 27330       Corn_(maize)___healthy
# 27331       Corn_(maize)___healthy
# 27332       Corn_(maize)___healthy
# 27333       Corn_(maize)___healthy
# 27334       Corn_(maize)___healthy
#
# [27335 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# Step 1: Split into 70% training and 30% dummy
train_df, dummy_df = train_test_split(df, train_size=0.7, shuffle=True, random_state=42)

# Step 2: Split dummy_df into 20% testing and 10% validation
test_df, valid_df = train_test_split(dummy_df, train_size=2/3, shuffle=True, random_state=42)

# %%
print(train_df.shape)
print(dummy_df.shape)
print(valid_df.shape)
print(test_df.shape)
# Out:
# (19134, 2)
# (8201, 2)
# (2734, 2)
# (5467, 2)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define ImageDataGenerator for training, validation, and test data
train_datagen = ImageDataGenerator(
    rescale=1./255,           # Normalize pixel values to [0, 1]
    rotation_range=20,        # Randomly rotate images in the range 0-20 degrees
    width_shift_range=0.2,    # Randomly shift images horizontally
    height_shift_range=0.2,   # Randomly shift images vertically
    shear_range=0.2,          # Shear transformation
    zoom_range=0.2,           # Random zoom
    horizontal_flip=True,     # Randomly flip images horizontally
    fill_mode='nearest'       # Fill missing pixels after transformation
)

valid_datagen = ImageDataGenerator(rescale=1./255)  # Only normalize
test_datagen = ImageDataGenerator(rescale=1./255)   # Only normalize

# Create data generators
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepaths',
    y_col='Labels',
    target_size=(224, 224),  # Resize images to match model input
    batch_size=32,
        class_mode='categorical',
    shuffle=True,
    seed=42
)

valid_generator = valid_datagen.flow_from_dataframe(
    dataframe=valid_df,
    x_col='Filepaths',
    y_col='Labels',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='Filepaths',
    y_col='Labels',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 19134 validated image filenames belonging to 21 classes.
# Found 2734 validated image filenames belonging to 21 classes.
# Found 5467 validated image filenames belonging to 21 classes.

# %%
print(f'Training samples: {train_generator.samples}')
print(f'Validation samples: {valid_generator.samples}')
print(f'Test samples: {test_generator.samples}')
# Out:
# Training samples: 19134
# Validation samples: 2734
# Test samples: 5467

# %%
from tensorflow.keras.models import Sequential
import keras
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import models, layers

input_shape = (224, 224, 3)  
n_classes = len(train_generator.class_indices)

model = Sequential([
    layers.ZeroPadding2D(padding=(1, 1), input_shape=input_shape),  
    layers.Conv2D(64, (5, 5), strides=(1, 1), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPool2D(pool_size=(2, 2)),

    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPool2D(pool_size=(2, 2)),

    layers.Conv2D(180, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPool2D(pool_size=(2, 2)),

    layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPool2D(pool_size=(2, 2)),

    layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPool2D(pool_size=(2, 2)),

    layers.Flatten(), 
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    

    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),

    layers.Dense(n_classes, activation='softmax')
])


model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=1e-4),
    metrics=['accuracy']
)

model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/zero_padding2d.py:72: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ zero_padding2d (ZeroPadding2D)       │ (None, 226, 226, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 226, 226, 64)        │           4,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 226, 226, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 113, 113, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 113, 113, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 113, 113, 128)       │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 56, 56, 180)         │         207,540 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 56, 56, 180)         │             720 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 28, 28, 180)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 28, 28, 256)         │         414,976 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 28, 28, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 14, 14, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 14, 14, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 14, 14, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 7, 7, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 12544)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │       3,211,520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 21)                  │           5,397 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,578,585 (17.47 MB)
#  Trainable params: 4,576,305 (17.46 MB)
#  Non-trainable params: 2,280 (8.91 KB)

# %%
history = model.fit(
    train_generator,
    batch_size=32,
    validation_data=valid_generator,
    epochs=50,
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 243s 365ms/step - accuracy: 0.4904 - loss: 1.8017 - val_accuracy: 0.5585 - val_loss: 1.5141
# Epoch 2/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 194s 321ms/step - accuracy: 0.7436 - loss: 0.8235 - val_accuracy: 0.7143 - val_loss: 1.1489
# Epoch 3/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 195s 321ms/step - accuracy: 0.8029 - loss: 0.5988 - val_accuracy: 0.6540 - val_loss: 1.4527
# Epoch 4/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 193s 319ms/step - accuracy: 0.8421 - loss: 0.4871 - val_accuracy: 0.5999 - val_loss: 1.7167
# Epoch 5/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 194s 321ms/step - accuracy: 0.8651 - loss: 0.4137 - val_accuracy: 0.7176 - val_loss: 1.1692
# Epoch 6/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 194s 321ms/step - accuracy: 0.8966 - loss: 0.3234 - val_accuracy: 0.7670 - val_loss: 0.8516
# Epoch 7/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 195s 321ms/step - accuracy: 0.9046 - loss: 0.2874 - val_accuracy: 0.8723 - val_loss: 0.3961
# Epoch 8/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 194s 320ms/step - accuracy: 0.9140 - loss: 0.2561 - val_accuracy: 0.6884 - val_loss: 1.6005
# Epoch 9/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 193s 320ms/step - accuracy: 0.9289 - loss: 0.2208 - val_accuracy: 0.7557 - val_loss: 1.1974
# Epoch 10/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 191s 316ms/step - accuracy: 0.9306 - loss: 0.2089 - val_accuracy: 0.8336 - val_loss: 0.7069
# Epoch 11/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 192s 318ms/step - accuracy: 0.9420 - loss: 0.1744 - val_accuracy: 0.8189 - val_loss: 0.8789
# Epoch 12/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 194s 321ms/step - accuracy: 0.9427 - loss: 0.1712 - val_accuracy: 0.8149 - val_loss: 0.6873
# Epoch 13/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 192s 317ms/step - accuracy: 0.9489 - loss: 0.1574 - val_accuracy: 0.8047 - val_loss: 0.9470
# Epoch 14/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 192s 317ms/step - accuracy: 0.9529 - loss: 0.1360 - val_accuracy: 0.8398 - val_loss: 0.5215
# Epoch 15/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 194s 320ms/step - accuracy: 0.9570 - loss: 0.1355 - val_accuracy: 0.6920 - val_loss: 1.5817
# Epoch 16/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 192s 317ms/step - accuracy: 0.9615 - loss: 0.1223 - val_accuracy: 0.8606 - val_loss: 0.6260
# Epoch 17/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 191s 315ms/step - accuracy: 0.9620 - loss: 0.1125 - val_accuracy: 0.8643 - val_loss: 0.5385
# Epoch 18/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 192s 317ms/step - accuracy: 0.9656 - loss: 0.1073 - val_accuracy: 0.8109 - val_loss: 0.7731
# Epoch 19/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 193s 319ms/step - accuracy: 0.9651 - loss: 0.1062 - val_accuracy: 0.9078 - val_loss: 0.2705
# Epoch 20/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 191s 315ms/step - accuracy: 0.9666 - loss: 0.0930 - val_accuracy: 0.7820 - val_loss: 1.1632
# Epoch 21/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 192s 317ms/step - accuracy: 0.9715 - loss: 0.0896 - val_accuracy: 0.9265 - val_loss: 0.3105
# Epoch 22/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 191s 315ms/step - accuracy: 0.9667 - loss: 0.1022 - val_accuracy: 0.9005 - val_loss: 0.4089
# Epoch 23/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 192s 318ms/step - accuracy: 0.9696 - loss: 0.0978 - val_accuracy: 0.9042 - val_loss: 0.3636
# Epoch 24/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 191s 316ms/step - accuracy: 0.9771 - loss: 0.0725 - val_accuracy: 0.8548 - val_loss: 0.7457
# Epoch 25/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 191s 316ms/step - accuracy: 0.9757 - loss: 0.0704 - val_accuracy: 0.9404 - val_loss: 0.2567
# Epoch 26/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 193s 319ms/step - accuracy: 0.9746 - loss: 0.0730 - val_accuracy: 0.9031 - val_loss: 0.6242
# Epoch 27/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 192s 317ms/step - accuracy: 0.9799 - loss: 0.0636 - val_accuracy: 0.8519 - val_loss: 0.8099
# Epoch 28/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 191s 315ms/step - accuracy: 0.9773 - loss: 0.0685 - val_accuracy: 0.9594 - val_loss: 0.1313
# Epoch 29/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 192s 317ms/step - accuracy: 0.9753 - loss: 0.0682 - val_accuracy: 0.8255 - val_loss: 0.9951
# Epoch 30/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 192s 318ms/step - accuracy: 0.9771 - loss: 0.0732 - val_accuracy: 0.9173 - val_loss: 0.4325
# Epoch 31/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 193s 319ms/step - accuracy: 0.9779 - loss: 0.0614 - val_accuracy: 0.8723 - val_loss: 0.6293
# Epoch 32/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 208s 344ms/step - accuracy: 0.9851 - loss: 0.0475 - val_accuracy: 0.8731 - val_loss: 0.6268
# Epoch 33/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 216s 357ms/step - accuracy: 0.9791 - loss: 0.0605 - val_accuracy: 0.7809 - val_loss: 1.3807
# Epoch 34/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 203s 336ms/step - accuracy: 0.9784 - loss: 0.0639 - val_accuracy: 0.9495 - val_loss: 0.2063
# Epoch 35/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 204s 337ms/step - accuracy: 0.9831 - loss: 0.0529 - val_accuracy: 0.9451 - val_loss: 0.2141
# Epoch 36/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 197s 325ms/step - accuracy: 0.9834 - loss: 0.0506 - val_accuracy: 0.9334 - val_loss: 0.2422
# Epoch 37/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 205s 339ms/step - accuracy: 0.9828 - loss: 0.0508 - val_accuracy: 0.8178 - val_loss: 1.1775
# Epoch 38/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 207s 342ms/step - accuracy: 0.9821 - loss: 0.0526 - val_accuracy: 0.9726 - val_loss: 0.0927
# Epoch 39/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 207s 343ms/step - accuracy: 0.9815 - loss: 0.0514 - val_accuracy: 0.9064 - val_loss: 0.4641
# Epoch 40/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 201s 332ms/step - accuracy: 0.9862 - loss: 0.0418 - val_accuracy: 0.8808 - val_loss: 0.6213
# Epoch 41/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 201s 332ms/step - accuracy: 0.9850 - loss: 0.0438 - val_accuracy: 0.9448 - val_loss: 0.2751
# Epoch 42/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 205s 338ms/step - accuracy: 0.9876 - loss: 0.0410 - val_accuracy: 0.9060 - val_loss: 0.4615
# Epoch 43/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 209s 345ms/step - accuracy: 0.9844 - loss: 0.0441 - val_accuracy: 0.9217 - val_loss: 0.3696
# Epoch 44/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 202s 334ms/step - accuracy: 0.9863 - loss: 0.0408 - val_accuracy: 0.9777 - val_loss: 0.0756
# Epoch 45/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 211s 348ms/step - accuracy: 0.9876 - loss: 0.0375 - val_accuracy: 0.9364 - val_loss: 0.2085
# Epoch 46/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 224s 370ms/step - accuracy: 0.9852 - loss: 0.0470 - val_accuracy: 0.9510 - val_loss: 0.2046
# Epoch 47/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 233s 384ms/step - accuracy: 0.9874 - loss: 0.0369 - val_accuracy: 0.9086 - val_loss: 0.3607
# Epoch 48/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 197s 325ms/step - accuracy: 0.9852 - loss: 0.0438 - val_accuracy: 0.9133 - val_loss: 0.3360
# Epoch 49/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 194s 321ms/step - accuracy: 0.9870 - loss: 0.0392 - val_accuracy: 0.9301 - val_loss: 0.2405
# Epoch 50/50
# 598/598 ━━━━━━━━━━━━━━━━━━━━ 195s 322ms/step - accuracy: 0.9884 - loss: 0.0349 - val_accuracy: 0.9645 - val_loss: 0.1335

# %%
test_loss, test_acc = model.evaluate(test_generator)
# Out:
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.9707 - loss: 0.0960

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

# Step 1: Get true labels from the test dataset
true_labels = test_generator.classes  

# Step 2: Get class names
class_names = list(test_generator.class_indices.keys())  

# Step 3: Get model predictions
y_pred_probs = model.predict(test_generator)  # Predict probabilities
y_pred = np.argmax(y_pred_probs, axis=1)  # Convert probabilities to class labels

# Step 4: Compute Confusion Matrix
cm = confusion_matrix(true_labels, y_pred)

# Step 5: Calculate Precision, Recall, and F1-score for each class
precision = np.diag(cm) / (np.sum(cm, axis=0) + 1e-9)  # TP / (TP + FP)
recall = np.diag(cm) / (np.sum(cm, axis=1) + 1e-9)  # TP / (TP + FN)
f1_score = 2 * (precision * recall) / (precision + recall + 1e-9)  # Harmonic mean

# Step 6: Store results in a DataFrame
results_df = pd.DataFrame({
    "Name of Crop": class_names,
    "Accuracy": [np.trace(cm) / np.sum(cm)] * len(class_names),  # Overall accuracy
    "Precision": precision,
    "Recall": recall,
    "F1 Score": f1_score
})

# Step 7: Print the results table
print("\nResults Table:\n")
print(results_df.to_string(index=False))

# Step 8: Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# Step 9: Print Classification Report (Alternative for better metrics)
print("\nClassification Report:\n")
print(classification_report(true_labels, y_pred, target_names=class_names))
# Out:
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step
#
# Results Table:
#
#                                       Name of Crop  Accuracy  Precision   Recall  F1 Score
#                                 Apple___Apple_scab  0.965978   1.000000 0.992857  0.996416
#                                  Apple___Black_rot  0.965978   0.982301 1.000000  0.991071
#                           Apple___Cedar_apple_rust  0.965978   0.982456 1.000000  0.991150
#                                    Apple___healthy  0.965978   0.997067 0.988372  0.992701
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot  0.965978   0.890909 0.970297  0.928910
#                        Corn_(maize)___Common_rust_  0.965978   0.995536 0.995536  0.995536
#                Corn_(maize)___Northern_Leaf_Blight  0.965978   0.979899 0.942029  0.960591
#                             Corn_(maize)___healthy  0.965978   0.991379 0.991379  0.991379
#                              Potato___Early_blight  0.965978   0.950450 1.000000  0.974596
#                               Potato___Late_blight  0.965978   0.994924 0.980000  0.987406
#                                   Potato___healthy  0.965978   0.600000 1.000000  0.750000
#                            Tomato___Bacterial_spot  0.965978   0.995349 0.983908  0.989595
#                              Tomato___Early_blight  0.965978   0.756972 0.989583  0.857788
#                               Tomato___Late_blight  0.965978   0.992063 0.954198  0.972763
#                                 Tomato___Leaf_Mold  0.965978   0.993789 0.958084  0.975610
#                        Tomato___Septoria_leaf_spot  0.965978   0.936675 0.994398  0.964674
#      Tomato___Spider_mites Two-spotted_spider_mite  0.965978   0.996721 0.918429  0.955975
#                               Tomato___Target_Spot  0.965978   1.000000 0.664336  0.798319
#             Tomato___Tomato_Yellow_Leaf_Curl_Virus  0.965978   0.988889 1.000000  0.994413
#                       Tomato___Tomato_mosaic_virus  0.965978   0.850575 1.000000  0.919255
#                                   Tomato___healthy  0.965978   0.951070 1.000000  0.974922
# Classification Report:
#
#                                                     precision    recall  f1-score   support
#
#                                 Apple___Apple_scab       1.00      0.99      1.00       140
#                                  Apple___Black_rot       0.98      1.00      0.99       111
#                           Apple___Cedar_apple_rust       0.98      1.00      0.99        56
#                                    Apple___healthy       1.00      0.99      0.99       344
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot       0.89      0.97      0.93       101
#                        Corn_(maize)___Common_rust_       1.00      1.00      1.00       224
#                Corn_(maize)___Northern_Leaf_Blight       0.98      0.94      0.96       207
#                             Corn_(maize)___healthy       0.99      0.99      0.99       232
#                              Potato___Early_blight       0.95      1.00      0.97       211
#                               Potato___Late_blight       0.99      0.98      0.99       200
#                                   Potato___healthy       0.60      1.00      0.75        27
#                            Tomato___Bacterial_spot       1.00      0.98      0.99       435
#                              Tomato___Early_blight       0.76      0.99      0.86       192
#                               Tomato___Late_blight       0.99      0.95      0.97       393
#                                 Tomato___Leaf_Mold       0.99      0.96      0.98       167
#                        Tomato___Septoria_leaf_spot       0.94      0.99      0.96       357
#      Tomato___Spider_mites Two-spotted_spider_mite       1.00      0.92      0.96       331
#                               Tomato___Target_Spot       1.00      0.66      0.80       286
#             Tomato___Tomato_Yellow_Leaf_Curl_Virus       0.99      1.00      0.99      1068
#                       Tomato___Tomato_mosaic_virus       0.85      1.00      0.92        74
#                                   Tomato___healthy       0.95      1.00      0.97       311
#
#                                           accuracy                           0.97      5467
#                                          macro avg       0.94      0.97      0.95      5467
#                                       weighted avg       0.97      0.97      0.97      5467

# %%
import matplotlib.pyplot as plt

# Extract Accuracy and Validation Accuracy from history
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(1, len(train_acc) + 1)  # Number of epochs

# Plot Training and Validation Accura cy
plt.figure(figsize=(8, 6))
plt.plot(epochs, train_acc, 'bo-', label='Training Accuracy')  # 'bo-' means blue circles with lines
plt.plot(epochs, val_acc, 'r^-', label='Validation Accuracy')  # 'r^-' means red triangles with lines

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Extract Loss and Validation Loss from training history
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(train_loss) + 1)  # Number of epochs

# Plot Training and Validation Loss
plt.figure(figsize=(8, 6))
plt.plot(epochs, train_loss, 'bo-', label='Training Loss')  # 'bo-' means blue circles with lines
plt.plot(epochs, val_loss, 'r^-', label='Validation Loss')  # 'r^-' means red triangles with lines

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss vs. Validation Loss')
plt.legend()
plt.grid(True)
plt.show()
